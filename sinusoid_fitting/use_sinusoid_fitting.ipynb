# %% [markdown]
# #This is an example of how to use the sinusoid_fitting code.

# %%
import sinusoid_fitting
reload(sinusoid_fitting)
import numpy as np

# %% [markdown]
# ## Load Data (a sinusoidal signal)

# %%
time, signal = np.loadtxt('../data/2015-05-21/ALL0001/F0001CH1.CSV', delimiter=',', 
                                usecols=[3, 4], unpack=True)

# %% [markdown]
# ## Fit Data

# %%
fit_parameters, fit_stds, covariance = sinusoid_fitting.fit_signal(time, signal)

# %% [markdown]
# ## Fit Parameters

# %%
print fit_parameters
# Out:
# {'phase': 0.43875395712002591, 'frequency': 49985.029277626913, 'amplitude': 0.33333951497794134, 'offset': -0.038669747633817177}

# %%
fit_parameters['amplitude']
# Out:
# 0.33333951497794134

# %% [markdown]
# ## Fit Uncertainty

# %%
print fit_stds
# Out:
# {'phase': 0.00082947952786513739, 'frequency': 3.2737319954604396, 'amplitude': 0.00019508874694828298, 'offset': 0.00013940592080727326}

# %% [markdown]
# ## Save a plot into a dated output directory

# %%
sinusoid_fitting.plot_signal_vs_fit(time, signal, fit_parameters, '1'.zfill(4))

# %% [markdown]
# ## Display the plot

# %%
from IPython.display import Image
Image(filename='../output/2015-06-16/0001.png')
